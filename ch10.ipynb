# %% [markdown]
# # 視覺化
#
# ## 郭耀仁

# %% [markdown]
# ## 視覺化的力量
#
# - [Hans Rosling](https://www.youtube.com/watch?v=jbkSRLYSojo)
#
# > He rose to international celebrity status after producing a [Ted Talk](https://www.ted.com/talks/hans_rosling_shows_the_best_stats_you_ve_ever_seen?language=zh-tw) in which he promoted the use of data to explore development issues.
# > [Hans Rosling - Wikipedia](https://en.wikipedia.org/wiki/Hans_Rosling)

# %% [markdown]
# ## Matplotlib
#
# - Python 基礎的繪圖套件
#
# ```python
# %matplotlib inline # 讓圖能夠在 Notebook 中顯示，不一定需要
# import matplotlib.pyplot as plt
# ```

# %% [markdown]
# ## Matplotlib（2）
#
# |繪圖函數|繪圖類型|
# |-------|-------|
# |`plt.bar()`|長條圖 bar plot|
# |`plt.scatter()`|散佈圖 scatter plot|
# |`plt.boxplot()`|盒鬚圖 box plot|
# |`plt.hist()`|直方圖 histogram|
# |`plt.plot()`|線圖 line plot|
# |`plt.contour()`|等高線圖 contour plot|

# %%
# plt.bar()
import numpy as np
import matplotlib.pyplot as plt

N = 5
ice_cream_sales = np.random.randint(50, 100, size = 5)
ind = np.arange(N)
width = 0.5
fig, ax = plt.subplots()
ax.bar(ind, ice_cream_sales, width, color = 'g')
ax.set_ylabel('Sales')
ax.set_title('Ice cream sales by flavor')
ax.set_xticks(ind)
ax.set_xticklabels(('Matcha', 'Chocolate', 'Vanilla', 'Coco', 'Strawberry'))
plt.show()

# %%
# plt.barh()
import numpy as np
import matplotlib.pyplot as plt

N = 5
ice_cream_sales = np.random.randint(50, 100, size = 5)
ind = np.arange(N)
width = 0.5
fig, ax = plt.subplots()
ax.barh(ind, ice_cream_sales, width, color = 'y')
ax.set_xlabel('Sales')
ax.set_title('Ice cream sales by flavor')
ax.set_yticks(ind)
ax.set_yticklabels(('Matcha', 'Chocolate', 'Vanilla', 'Coco', 'Strawberry'))
plt.show()

# %%
# plt.scatter()
# 探索兩個數值的關係

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-5, 6)
y = x**2
plt.scatter(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("$y = x^2$") # 支援 LaTex Math 語法
plt.grid(True)
plt.show()

# %%
# plt.boxplot()

import numpy as np
import matplotlib.pyplot as plt

data_size = (100, 1)
data_norm = np.random.normal(size = data_size)
data_lognormal = np.random.lognormal(size = data_size)
data_unif = np.random.uniform(size = data_size)
data = np.hstack((data_norm, data_unif, data_unif))
labels = ['Normal', 'Lognormal', 'Uniform']
fig, ax = plt.subplots()
ax.boxplot(data, labels = labels)
ax.set_title('Distribution types')
plt.show()

# %%
# plt.hist()

import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(size = (10000, 1))
fig, ax = plt.subplots()
ax.hist(data)
ax.set_title('Normal Distribution')
ax.set_ylabel("Freq")
plt.show()

# %%
# plt.plot()

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-np.pi, np.pi, 0.01)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("$y = \sin(x)$")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Matplotlib（3）
#
# - 網格畫布

# %%
# 2 X 1
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 50)
y = np.sin(x)
plt.subplots(2, 1, sharex = True)
plt.subplot(2, 1, 1).plot(x, y)
plt.subplot(2, 1, 1).set_title('Sharing X Axis')
plt.subplot(2, 1, 2).scatter(x, y, color = 'r')
plt.tight_layout()
plt.show()

# %%
# 1 X 2
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 50)
y = np.sin(x)
f, axes = plt.subplots(1, 2, sharey = True)
axes[0].plot(x, y)
axes[0].set_title('Sharing Y Axis')
axes[1].scatter(x, y, color = 'r')
plt.tight_layout()
plt.show()

# %%
# 2 X 2
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 25)
y = np.sin(x)
f, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2, 2, sharex = True, sharey = True)
ax0.plot(x, y)
ax0.set_title('Sharing x per column, y per row')
ax1.scatter(x, y, color = 'r')
ax2.plot(x, y, color = 'g')
ax3.scatter(x, y, color = 'y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 等高線圖
#
# - `numpy.meshgrid()` 可以幫我們把一維數列分別往水平/垂直方向延伸為矩陣

# %%
import numpy as np

u = np.arange(start = -5, stop = 5, step = 0.1)
x, y = np.meshgrid(u, u)
print(x)
print("\n")
print(y)
# Out:
# [[-5.  -4.9 -4.8 ...,  4.7  4.8  4.9]
#  [-5.  -4.9 -4.8 ...,  4.7  4.8  4.9]
#  [-5.  -4.9 -4.8 ...,  4.7  4.8  4.9]
#  ...,
#  [-5.  -4.9 -4.8 ...,  4.7  4.8  4.9]
#  [-5.  -4.9 -4.8 ...,  4.7  4.8  4.9]
#  [-5.  -4.9 -4.8 ...,  4.7  4.8  4.9]]
#
#
# [[-5.  -5.  -5.  ..., -5.  -5.  -5. ]
#  [-4.9 -4.9 -4.9 ..., -4.9 -4.9 -4.9]
#  [-4.8 -4.8 -4.8 ..., -4.8 -4.8 -4.8]
#  ...,
#  [ 4.7  4.7  4.7 ...,  4.7  4.7  4.7]
#  [ 4.8  4.8  4.8 ...,  4.8  4.8  4.8]
#  [ 4.9  4.9  4.9 ...,  4.9  4.9  4.9]]

# %% [markdown]
# ## 等高線圖（2）
#
# - 等高線圖需要第三個維度：`z` 來表示高度（顏色）

# %%
import numpy as np

u = np.arange(start = -5, stop = 5, step = 0.1)
x, y = np.meshgrid(u, u)
z = x**2 + y**2
print(z)
# Out:
# [[ 50.    49.01  48.04 ...,  47.09  48.04  49.01]
#  [ 49.01  48.02  47.05 ...,  46.1   47.05  48.02]
#  [ 48.04  47.05  46.08 ...,  45.13  46.08  47.05]
#  ...,
#  [ 47.09  46.1   45.13 ...,  44.18  45.13  46.1 ]
#  [ 48.04  47.05  46.08 ...,  45.13  46.08  47.05]
#  [ 49.01  48.02  47.05 ...,  46.1   47.05  48.02]]

# %% [markdown]
# ## 等高線圖（3）
#
# - `contour()` 是沒有填色的

# %%
import numpy as np

u = np.arange(start = -5, stop = 5, step = 0.1)
x, y = np.meshgrid(u, u)
z = x**2 + y**2
plt.contour(x, y, z)
plt.show()

# %% [markdown]
# ## 等高線圖（4）
#
# - `contourf()` 是有填色的

# %%
import numpy as np
import matplotlib.pyplot as plt

u = np.arange(start = -5, stop = 5, step = 0.1)
x, y = np.meshgrid(u, u)
z = x**2 + y**2
plt.contourf(x, y, z)
plt.show()

# %% [markdown]
# ## 等高線圖（5）
#
# - 為什麼要知道等高線圖怎麼畫？

# %% [markdown]
# ## 視覺化像素
#
# - 讀入範例資料

# %%
from sklearn import datasets

digits = datasets.load_digits()
print(digits.images.shape)
print(digits.images[0].shape)
# Out:
# (1797, 8, 8)
# (8, 8)

# %%
# 視覺化像素（2）
# 使用 `imshow()` 方法

from sklearn import datasets
import matplotlib.pyplot as plt

digits = datasets.load_digits()
plt.imshow(digits.images[0], cmap = "binary")
plt.show()

# %%
# 視覺化像素（3）
# 看 10 張

from sklearn import datasets
import matplotlib.pyplot as plt

digits = datasets.load_digits()
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(digits.images[i], cmap = "binary")
plt.show()

# %%
# 視覺化像素（4）
# 看 10 張
# cmap 改用 "gray"

from sklearn import datasets
import matplotlib.pyplot as plt

digits = datasets.load_digits()
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(digits.images[i], cmap = "gray")
plt.show()

# %% [markdown]
# ## 隨堂練習
#
# - 建立一個 (3, 2) 的網格畫布
# - 分別畫出 $\sin(x)$、$\cos(x)$、$\tan(x)$、$\arcsin(x)$、$\arccos(x)$ 與 $\arctan(x)$ 在 $-3\pi$ 與 $3\pi$ 之間的函數圖形

# %% [markdown]
# ## 延伸閱讀
#
# - [Matplotlib Gallery](http://matplotlib.org/gallery.html)
# - [Seaborn: statistical data visualization](https://seaborn.pydata.org/)
# - [Bokeh](http://bokeh.pydata.org/en/latest/)
